# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder,OrdinalEncoder
import seaborn as sns
import matplotlib as plt
import matplotlib.pyplot as pl
from data_manager import DataManager as dm
import numpy as np
import math

# %% [markdown]
# # Data Collection and Project Initialization

# %%
train_values=pd.read_csv('train_values.csv')
train_labels=pd.read_csv('train_labels.csv')
df_info = pd.read_csv('./data/data_info.csv')
df=pd.merge(train_values,train_labels, on='building_id')

# %% [markdown]
# # Data Exploration and Preprocessing

# %% [markdown]
# ## Raw Data Analysis.
# We set the scale of features by using the data `scale_type` array.
# Then, create an initial quality report for all raw data..

# %%
df.describe()
# Out:
#         building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# count  2.606010e+05   260601.000000   260601.000000   260601.000000
# mean   5.256755e+05       13.900353      701.074685     6257.876148
# std    3.045450e+05        8.033617      412.710734     3646.369645
# min    4.000000e+00        0.000000        0.000000        0.000000
# 25%    2.611900e+05        7.000000      350.000000     3073.000000
# 50%    5.257570e+05       12.000000      702.000000     6270.000000
# 75%    7.897620e+05       21.000000     1050.000000     9412.000000
# max    1.052934e+06       30.000000     1427.000000    12567.000000
#
#        count_floors_pre_eq            age  area_percentage  height_percentage  \
# count        260601.000000  260601.000000    260601.000000      260601.000000
# mean              2.129723      26.535029         8.018051           5.434365
# std               0.727665      73.565937         4.392231           1.918418
# min               1.000000       0.000000         1.000000           2.000000
# 25%               2.000000      10.000000         5.000000           4.000000
# 50%               2.000000      15.000000         7.000000           5.000000
# 75%               2.000000      30.000000         9.000000           6.000000
# max               9.000000     995.000000       100.000000          32.000000
#
#        has_superstructure_adobe_mud  has_superstructure_mud_mortar_stone  ...  \
# count                 260601.000000                        260601.000000  ...
# mean                       0.088645                             0.761935  ...
# std                        0.284231                             0.425900  ...
# min                        0.000000                             0.000000  ...
# 25%                        0.000000                             1.000000  ...
# 50%                        0.000000                             1.000000  ...
# 75%                        0.000000                             1.000000  ...
# max                        1.000000                             1.000000  ...
#
#        has_secondary_use_hotel  has_secondary_use_rental  \
# count            260601.000000             260601.000000
# mean                  0.033626                  0.008101
# std                   0.180265                  0.089638
# min                   0.000000                  0.000000
# 25%                   0.000000                  0.000000
# 50%                   0.000000                  0.000000
# 75%                   0.000000                  0.000000
# max                   1.000000                  1.000000
#
#        has_secondary_use_institution  has_secondary_use_school  \
# count                  260601.000000             260601.000000
# mean                        0.000940                  0.000361
# std                         0.030647                  0.018989
# min                         0.000000                  0.000000
# 25%                         0.000000                  0.000000
# 50%                         0.000000                  0.000000
# 75%                         0.000000                  0.000000
# max                         1.000000                  1.000000
#
#        has_secondary_use_industry  has_secondary_use_health_post  \
# count               260601.000000                  260601.000000
# mean                     0.001071                       0.000188
# std                      0.032703                       0.013711
# min                      0.000000                       0.000000
# 25%                      0.000000                       0.000000
# 50%                      0.000000                       0.000000
# 75%                      0.000000                       0.000000
# max                      1.000000                       1.000000
#
#        has_secondary_use_gov_office  has_secondary_use_use_police  \
# count                 260601.000000                 260601.000000
# mean                       0.000146                      0.000088
# std                        0.012075                      0.009394
# min                        0.000000                      0.000000
# 25%                        0.000000                      0.000000
# 50%                        0.000000                      0.000000
# 75%                        0.000000                      0.000000
# max                        1.000000                      1.000000
#
#        has_secondary_use_other   damage_grade
# count            260601.000000  260601.000000
# mean                  0.005119       2.238272
# std                   0.071364       0.611814
# min                   0.000000       1.000000
# 25%                   0.000000       2.000000
# 50%                   0.000000       2.000000
# 75%                   0.000000       3.000000
# max                   1.000000       3.000000
#
# [8 rows x 32 columns]

# %%
data_report = dm.data_analyser(df, df_info['type'].to_list())
data_report['df']
# Out:
#                                         Cardinality (#)    Scale  Miss (#)  \
# Feature
# building_id                                      260601       id         0
# geo_level_1_id                                       31       id         0
# geo_level_2_id                                     1414       id         0
# geo_level_3_id                                    11595       id         0
# count_floors_pre_eq                                   9  nominal         0
# age                                                  42    ratio         0
# area_percentage                                      84    ratio         0
# height_percentage                                    27    ratio         0
# land_surface_condition                                3  nominal         0
# foundation_type                                       5  nominal         0
# roof_type                                             3  nominal         0
# ground_floor_type                                     5  nominal         0
# other_floor_type                                      4  nominal         0
# position                                              4  nominal         0
# plan_configuration                                   10  nominal         0
# has_superstructure_adobe_mud                          2  nominal         0
# has_superstructure_mud_mortar_stone                   2  nominal         0
# has_superstructure_stone_flag                         2  nominal         0
# has_superstructure_cement_mortar_stone                2  nominal         0
# has_superstructure_mud_mortar_brick                   2  nominal         0
# has_superstructure_cement_mortar_brick                2  nominal         0
# has_superstructure_timber                             2  nominal         0
# has_superstructure_bamboo                             2  nominal         0
# has_superstructure_rc_non_engineered                  2  nominal         0
# has_superstructure_rc_engineered                      2  nominal         0
# has_superstructure_other                              2  nominal         0
# legal_ownership_status                                4  nominal         0
# count_families                                       10  nominal         0
# has_secondary_use                                     2  nominal         0
# has_secondary_use_agriculture                         2  nominal         0
# has_secondary_use_hotel                               2  nominal         0
# has_secondary_use_rental                              2  nominal         0
# has_secondary_use_institution                         2  nominal         0
# has_secondary_use_school                              2  nominal         0
# has_secondary_use_industry                            2  nominal         0
# has_secondary_use_health_post                         2  nominal         0
# has_secondary_use_gov_office                          2  nominal         0
# has_secondary_use_use_police                          2  nominal         0
# has_secondary_use_other                               2  nominal         0
# damage_grade                                          3  nominal         0
#
#                                         Miss (%)  \
# Feature
# building_id                                  0.0
# geo_level_1_id                               0.0
# geo_level_2_id                               0.0
# geo_level_3_id                               0.0
# count_floors_pre_eq                          0.0
# age                                          0.0
# area_percentage                              0.0
# height_percentage                            0.0
# land_surface_condition                       0.0
# foundation_type                              0.0
# roof_type                                    0.0
# ground_floor_type                            0.0
# other_floor_type                             0.0
# position                                     0.0
# plan_configuration                           0.0
# has_superstructure_adobe_mud                 0.0
# has_superstructure_mud_mortar_stone          0.0
# has_superstructure_stone_flag                0.0
# has_superstructure_cement_mortar_stone       0.0
# has_superstructure_mud_mortar_brick          0.0
# has_superstructure_cement_mortar_brick       0.0
# has_superstructure_timber                    0.0
# has_superstructure_bamboo                    0.0
# has_superstructure_rc_non_engineered         0.0
# has_superstructure_rc_engineered             0.0
# has_superstructure_other                     0.0
# legal_ownership_status                       0.0
# count_families                               0.0
# has_secondary_use                            0.0
# has_secondary_use_agriculture                0.0
# has_secondary_use_hotel                      0.0
# has_secondary_use_rental                     0.0
# has_secondary_use_institution                0.0
# has_secondary_use_school                     0.0
# has_secondary_use_industry                   0.0
# has_secondary_use_health_post                0.0
# has_secondary_use_gov_office                 0.0
# has_secondary_use_use_police                 0.0
# has_secondary_use_other                      0.0
# damage_grade                                 0.0
#
#                                                                                    Domain  \
# Feature
# building_id                             [802906, 28830, 94947, 590882, 201944, 333020,...
# geo_level_1_id                          [6, 8, 21, 22, 11, 9, 20, 0, 26, 17, 12, 18, 4...
# geo_level_2_id                          [487, 900, 363, 418, 131, 558, 475, 323, 757, ...
# geo_level_3_id                          [12198, 2812, 8973, 10694, 1488, 6089, 12066, ...
# count_floors_pre_eq                                           [2, 3, 1, 4, 5, 6, 7, 8, 9]
# age                                     [30, 10, 25, 0, 15, 20, 45, 55, 5, 40, 80, 60,...
# area_percentage                         [6, 8, 5, 9, 3, 13, 7, 4, 12, 16, 11, 27, 10, ...
# height_percentage                       [5, 7, 9, 4, 6, 3, 10, 8, 2, 32, 12, 11, 13, 1...
# land_surface_condition                                                          [t, o, n]
# foundation_type                                                           [r, w, i, u, h]
# roof_type                                                                       [n, q, x]
# ground_floor_type                                                         [f, x, v, z, m]
# other_floor_type                                                             [q, x, j, s]
# position                                                                     [t, s, j, o]
# plan_configuration                                         [d, u, s, q, m, c, a, n, f, o]
# has_superstructure_adobe_mud                                                       [1, 0]
# has_superstructure_mud_mortar_stone                                                [1, 0]
# has_superstructure_stone_flag                                                      [0, 1]
# has_superstructure_cement_mortar_stone                                             [0, 1]
# has_superstructure_mud_mortar_brick                                                [0, 1]
# has_superstructure_cement_mortar_brick                                             [0, 1]
# has_superstructure_timber                                                          [0, 1]
# has_superstructure_bamboo                                                          [0, 1]
# has_superstructure_rc_non_engineered                                               [0, 1]
# has_superstructure_rc_engineered                                                   [0, 1]
# has_superstructure_other                                                           [0, 1]
# legal_ownership_status                                                       [v, a, r, w]
# count_families                                             [1, 0, 2, 3, 4, 5, 6, 7, 9, 8]
# has_secondary_use                                                                  [0, 1]
# has_secondary_use_agriculture                                                      [0, 1]
# has_secondary_use_hotel                                                            [0, 1]
# has_secondary_use_rental                                                           [0, 1]
# has_secondary_use_institution                                                      [0, 1]
# has_secondary_use_school                                                           [0, 1]
# has_secondary_use_industry                                                         [0, 1]
# has_secondary_use_health_post                                                      [0, 1]
# has_secondary_use_gov_office                                                       [0, 1]
# has_secondary_use_use_police                                                       [0, 1]
# has_secondary_use_other                                                            [0, 1]
# damage_grade                                                                    [3, 2, 1]
#
#                                        Stored_data_type
# Feature
# building_id                                       int64
# geo_level_1_id                                    int64
# geo_level_2_id                                    int64
# geo_level_3_id                                    int64
# count_floors_pre_eq                               int64
# age                                               int64
# area_percentage                                   int64
# height_percentage                                 int64
# land_surface_condition                           object
# foundation_type                                  object
# roof_type                                        object
# ground_floor_type                                object
# other_floor_type                                 object
# position                                         object
# plan_configuration                               object
# has_superstructure_adobe_mud                      int64
# has_superstructure_mud_mortar_stone               int64
# has_superstructure_stone_flag                     int64
# has_superstructure_cement_mortar_stone            int64
# has_superstructure_mud_mortar_brick               int64
# has_superstructure_cement_mortar_brick            int64
# has_superstructure_timber                         int64
# has_superstructure_bamboo                         int64
# has_superstructure_rc_non_engineered              int64
# has_superstructure_rc_engineered                  int64
# has_superstructure_other                          int64
# legal_ownership_status                           object
# count_families                                    int64
# has_secondary_use                                 int64
# has_secondary_use_agriculture                     int64
# has_secondary_use_hotel                           int64
# has_secondary_use_rental                          int64
# has_secondary_use_institution                     int64
# has_secondary_use_school                          int64
# has_secondary_use_industry                        int64
# has_secondary_use_health_post                     int64
# has_secondary_use_gov_office                      int64
# has_secondary_use_use_police                      int64
# has_secondary_use_other                           int64
# damage_grade                                      int64

# %%
df_num = df.loc[:,df.dtypes!=np.object]
df_cat = df.loc[:,df.dtypes==np.object]
# Out:
# <ipython-input-5-be1d37bd3f61>:1: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   df_num = df.loc[:,df.dtypes!=np.object]
# <ipython-input-5-be1d37bd3f61>:2: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   df_cat = df.loc[:,df.dtypes==np.object]

# %% [markdown]
# ## Numerical Data Analysis

# %% [markdown]
# ### Identifying Null values

# %% [markdown]
# #### As there are no null values no further processing is required

# %%
df_num.isnull().sum().sort_values(ascending=False)
# Out:
# building_id                               0
# geo_level_1_id                            0
# has_secondary_use_other                   0
# has_secondary_use_use_police              0
# has_secondary_use_gov_office              0
# has_secondary_use_health_post             0
# has_secondary_use_industry                0
# has_secondary_use_school                  0
# has_secondary_use_institution             0
# has_secondary_use_rental                  0
# has_secondary_use_hotel                   0
# has_secondary_use_agriculture             0
# has_secondary_use                         0
# count_families                            0
# has_superstructure_other                  0
# has_superstructure_rc_engineered          0
# has_superstructure_rc_non_engineered      0
# has_superstructure_bamboo                 0
# has_superstructure_timber                 0
# has_superstructure_cement_mortar_brick    0
# has_superstructure_mud_mortar_brick       0
# has_superstructure_cement_mortar_stone    0
# has_superstructure_stone_flag             0
# has_superstructure_mud_mortar_stone       0
# has_superstructure_adobe_mud              0
# height_percentage                         0
# area_percentage                           0
# age                                       0
# count_floors_pre_eq                       0
# geo_level_3_id                            0
# geo_level_2_id                            0
# damage_grade                              0
# dtype: int64

# %% [markdown]
# ### Identifying Outliers

# %%
#OUTLIER_MAX_DIST = 1.5
df1=df_num
col_list=[]
for (name, series) in df1.iteritems():
    if series.dtype != 'object':
        col_list.append(name)

fig, ax = pl.subplots(figsize=(20,20)) # get a bigger figure
df_for_hist = df[col_list]

df_for_hist.hist(bins=10, alpha=0.5, ax=ax)
# Out:
# <ipython-input-7-9acd41626d19>:11: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   df_for_hist.hist(bins=10, alpha=0.5, ax=ax)
# array([[<AxesSubplot:title={'center':'building_id'}>,
#         <AxesSubplot:title={'center':'geo_level_1_id'}>,
#         <AxesSubplot:title={'center':'geo_level_2_id'}>,
#         <AxesSubplot:title={'center':'geo_level_3_id'}>,
#         <AxesSubplot:title={'center':'count_floors_pre_eq'}>,
#         <AxesSubplot:title={'center':'age'}>],
#        [<AxesSubplot:title={'center':'area_percentage'}>,
#         <AxesSubplot:title={'center':'height_percentage'}>,
#         <AxesSubplot:title={'center':'has_superstructure_adobe_mud'}>,
#         <AxesSubplot:title={'center':'has_superstructure_mud_mortar_stone'}>,
#         <AxesSubplot:title={'center':'has_superstructure_stone_flag'}>,
#         <AxesSubplot:title={'center':'has_superstructure_cement_mortar_stone'}>],
#        [<AxesSubplot:title={'center':'has_superstructure_mud_mortar_brick'}>,
#         <AxesSubplot:title={'center':'has_superstructure_cement_mortar_brick'}>,
#         <AxesSubplot:title={'center':'has_superstructure_timber'}>,
#         <AxesSubplot:title={'center':'has_superstructure_bamboo'}>,
#         <AxesSubplot:title={'center':'has_superstructure_rc_non_engineered'}>,
#         <AxesSubplot:title={'center':'has_superstructure_rc_engineered'}>],
#        [<AxesSubplot:title={'center':'has_superstructure_other'}>,
#         <AxesSubplot:title={'center':'count_families'}>,
#         <AxesSubplot:title={'center':'has_secondary_use'}>,
#         <AxesSubplot:title={'center':'has_secondary_use_agriculture'}>,
#         <AxesSubplot:title={'center':'has_secondary_use_hotel'}>,
#         <AxesSubplot:title={'center':'has_secondary_use_rental'}>],
#        [<AxesSubplot:title={'center':'has_secondary_use_institution'}>,
#         <AxesSubplot:title={'center':'has_secondary_use_school'}>,
#         <AxesSubplot:title={'center':'has_secondary_use_industry'}>,
#         <AxesSubplot:title={'center':'has_secondary_use_health_post'}>,
#         <AxesSubplot:title={'center':'has_secondary_use_gov_office'}>,
#         <AxesSubplot:title={'center':'has_secondary_use_use_police'}>],
#        [<AxesSubplot:title={'center':'has_secondary_use_other'}>,
#         <AxesSubplot:title={'center':'damage_grade'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
#boxplotting interval scale data before removing outliers
sns.boxplot(x=df_num['age'])
# Out:
# <AxesSubplot:xlabel='age'>

# %%
sns.boxplot(x=df_num['area_percentage'])
# Out:
# <AxesSubplot:xlabel='area_percentage'>

# %%
sns.boxplot(x=df_num['height_percentage'])
# Out:
# <AxesSubplot:xlabel='height_percentage'>

# %%
sns.boxplot(x=df_num['geo_level_1_id'])
# Out:
# <AxesSubplot:xlabel='geo_level_1_id'>

# %%
sns.boxplot(x=df_num['geo_level_2_id'])
# Out:
# <AxesSubplot:xlabel='geo_level_2_id'>

# %%
sns.boxplot(x=df_num['geo_level_3_id'])
# Out:
# <AxesSubplot:xlabel='geo_level_3_id'>

# %%
sns.boxplot(x=df_num['count_floors_pre_eq'])
# Out:
# <AxesSubplot:xlabel='count_floors_pre_eq'>

# %%
sns.boxplot(x=df_num['has_superstructure_adobe_mud'])
# Out:
# <AxesSubplot:xlabel='has_superstructure_adobe_mud'>

# %%
sns.boxplot(x=df_num['has_superstructure_mud_mortar_stone'])
# Out:
# <AxesSubplot:xlabel='has_superstructure_mud_mortar_stone'>

# %%
sns.boxplot(x=df_num['has_superstructure_stone_flag'])
# Out:
# <AxesSubplot:xlabel='has_superstructure_stone_flag'>

# %% [markdown]
# ### Custom function to clear outliers

# %%
def cap_data(d):
    for col in d.columns:
        print("capping the ",col)
        if (((d[col].dtype)=='float64') | ((d[col].dtype)=='int64')):
            percentiles = d[col].quantile([0.1,0.9]).values
            d[col][df[col] <= percentiles[0]] = percentiles[0]
            d[col][df[col] >= percentiles[1]] = percentiles[1]
        else:
            d[col]=d[col]
    return d

# %% [markdown]
# ##### removing Outliers

# %%
df_num_cleaned=cap_data(df_num.drop(['damage_grade',"building_id"],axis=1))
# Out:
# capping the  geo_level_1_id
# capping the  geo_level_2_id
# capping the  geo_level_3_id
# capping the  count_floors_pre_eq
# capping the  age
# capping the  area_percentage
# capping the  height_percentage
# capping the  has_superstructure_adobe_mud
# capping the  has_superstructure_mud_mortar_stone
# capping the  has_superstructure_stone_flag
# capping the  has_superstructure_cement_mortar_stone
# capping the  has_superstructure_mud_mortar_brick
# capping the  has_superstructure_cement_mortar_brick
# capping the  has_superstructure_timber
# capping the  has_superstructure_bamboo
# capping the  has_superstructure_rc_non_engineered
# capping the  has_superstructure_rc_engineered
# capping the  has_superstructure_other
# capping the  count_families
# capping the  has_secondary_use
# capping the  has_secondary_use_agriculture
# capping the  has_secondary_use_hotel
# capping the  has_secondary_use_rental
# capping the  has_secondary_use_institution
# capping the  has_secondary_use_school
# capping the  has_secondary_use_industry
# capping the  has_secondary_use_health_post
# capping the  has_secondary_use_gov_office
# capping the  has_secondary_use_use_police
# capping the  has_secondary_use_other

# %% [markdown]
# ### Numerical Data Quality Report

# %%
dm.numerical_report(df_num_cleaned, 1.5, out_method='qrt')
# Out:
#                                          Count  Missing (%)  Cardinality (#)  \
# Feature
# geo_level_1_id                          260601          0.0               23
# geo_level_2_id                          260601          0.0             1121
# geo_level_3_id                          260601          0.0             9283
# count_floors_pre_eq                     260601          0.0                3
# age                                     260601          0.0                9
# area_percentage                         260601          0.0               10
# height_percentage                       260601          0.0                6
# has_superstructure_adobe_mud            260601          0.0                1
# has_superstructure_mud_mortar_stone     260601          0.0                2
# has_superstructure_stone_flag           260601          0.0                1
# has_superstructure_cement_mortar_stone  260601          0.0                1
# has_superstructure_mud_mortar_brick     260601          0.0                1
# has_superstructure_cement_mortar_brick  260601          0.0                1
# has_superstructure_timber               260601          0.0                2
# has_superstructure_bamboo               260601          0.0                1
# has_superstructure_rc_non_engineered    260601          0.0                1
# has_superstructure_rc_engineered        260601          0.0                1
# has_superstructure_other                260601          0.0                1
# count_families                          260601          0.0                1
# has_secondary_use                       260601          0.0                2
# has_secondary_use_agriculture           260601          0.0                1
# has_secondary_use_hotel                 260601          0.0                1
# has_secondary_use_rental                260601          0.0                1
# has_secondary_use_institution           260601          0.0                1
# has_secondary_use_school                260601          0.0                1
# has_secondary_use_industry              260601          0.0                1
# has_secondary_use_health_post           260601          0.0                1
# has_secondary_use_gov_office            260601          0.0                1
# has_secondary_use_use_police            260601          0.0                1
# has_secondary_use_other                 260601          0.0                1
#
#                                          Min      Q1  Median      Q3    Max  \
# Feature
# geo_level_1_id                             4     7.0    12.0    21.0     26
# geo_level_2_id                           142   350.0   702.0  1050.0   1273
# geo_level_3_id                          1219  3073.0  6270.0  9412.0  11286
# count_floors_pre_eq                        1     2.0     2.0     2.0      3
# age                                        5    10.0    15.0    30.0     45
# area_percentage                            4     5.0     7.0     9.0     13
# height_percentage                          3     4.0     5.0     6.0      8
# has_superstructure_adobe_mud               0     0.0     0.0     0.0      0
# has_superstructure_mud_mortar_stone        0     1.0     1.0     1.0      1
# has_superstructure_stone_flag              0     0.0     0.0     0.0      0
# has_superstructure_cement_mortar_stone     0     0.0     0.0     0.0      0
# has_superstructure_mud_mortar_brick        0     0.0     0.0     0.0      0
# has_superstructure_cement_mortar_brick     0     0.0     0.0     0.0      0
# has_superstructure_timber                  0     0.0     0.0     1.0      1
# has_superstructure_bamboo                  0     0.0     0.0     0.0      0
# has_superstructure_rc_non_engineered       0     0.0     0.0     0.0      0
# has_superstructure_rc_engineered           0     0.0     0.0     0.0      0
# has_superstructure_other                   0     0.0     0.0     0.0      0
# count_families                             1     1.0     1.0     1.0      1
# has_secondary_use                          0     0.0     0.0     0.0      1
# has_secondary_use_agriculture              0     0.0     0.0     0.0      0
# has_secondary_use_hotel                    0     0.0     0.0     0.0      0
# has_secondary_use_rental                   0     0.0     0.0     0.0      0
# has_secondary_use_institution              0     0.0     0.0     0.0      0
# has_secondary_use_school                   0     0.0     0.0     0.0      0
# has_secondary_use_industry                 0     0.0     0.0     0.0      0
# has_secondary_use_health_post              0     0.0     0.0     0.0      0
# has_secondary_use_gov_office               0     0.0     0.0     0.0      0
# has_secondary_use_use_police               0     0.0     0.0     0.0      0
# has_secondary_use_other                    0     0.0     0.0     0.0      0
#
#                                            Mean  Std.Dev  Outlier_lower  \
# Feature
# geo_level_1_id                            13.93     7.68          -14.0
# geo_level_2_id                           699.53   388.14         -700.0
# geo_level_3_id                          6256.48  3452.38        -6435.5
# count_floors_pre_eq                        2.09     0.63            2.0
# age                                       19.85    13.30          -20.0
# area_percentage                            7.63     2.78           -1.0
# height_percentage                          5.35     1.49            1.0
# has_superstructure_adobe_mud               0.00     0.00            0.0
# has_superstructure_mud_mortar_stone        0.76     0.43            1.0
# has_superstructure_stone_flag              0.00     0.00            0.0
# has_superstructure_cement_mortar_stone     0.00     0.00            0.0
# has_superstructure_mud_mortar_brick        0.00     0.00            0.0
# has_superstructure_cement_mortar_brick     0.00     0.00            0.0
# has_superstructure_timber                  0.25     0.44           -1.5
# has_superstructure_bamboo                  0.00     0.00            0.0
# has_superstructure_rc_non_engineered       0.00     0.00            0.0
# has_superstructure_rc_engineered           0.00     0.00            0.0
# has_superstructure_other                   0.00     0.00            0.0
# count_families                             1.00     0.00            1.0
# has_secondary_use                          0.11     0.32            0.0
# has_secondary_use_agriculture              0.00     0.00            0.0
# has_secondary_use_hotel                    0.00     0.00            0.0
# has_secondary_use_rental                   0.00     0.00            0.0
# has_secondary_use_institution              0.00     0.00            0.0
# has_secondary_use_school                   0.00     0.00            0.0
# has_secondary_use_industry                 0.00     0.00            0.0
# has_secondary_use_health_post              0.00     0.00            0.0
# has_secondary_use_gov_office               0.00     0.00            0.0
# has_secondary_use_use_police               0.00     0.00            0.0
# has_secondary_use_other                    0.00     0.00            0.0
#
#                                         Outlier_upper  Number of outliers  \
# Feature
# geo_level_1_id                                   42.0                   0
# geo_level_2_id                                 2100.0                   0
# geo_level_3_id                                18920.5                   0
# count_floors_pre_eq                               2.0              103978
# age                                              60.0                   0
# area_percentage                                  15.0                   0
# height_percentage                                 9.0                   0
# has_superstructure_adobe_mud                      0.0                   0
# has_superstructure_mud_mortar_stone               1.0               62040
# has_superstructure_stone_flag                     0.0                   0
# has_superstructure_cement_mortar_stone            0.0                   0
# has_superstructure_mud_mortar_brick               0.0                   0
# has_superstructure_cement_mortar_brick            0.0                   0
# has_superstructure_timber                         2.5                   0
# has_superstructure_bamboo                         0.0                   0
# has_superstructure_rc_non_engineered              0.0                   0
# has_superstructure_rc_engineered                  0.0                   0
# has_superstructure_other                          0.0                   0
# count_families                                    1.0                   0
# has_secondary_use                                 0.0               29156
# has_secondary_use_agriculture                     0.0                   0
# has_secondary_use_hotel                           0.0                   0
# has_secondary_use_rental                          0.0                   0
# has_secondary_use_institution                     0.0                   0
# has_secondary_use_school                          0.0                   0
# has_secondary_use_industry                        0.0                   0
# has_secondary_use_health_post                     0.0                   0
# has_secondary_use_gov_office                      0.0                   0
# has_secondary_use_use_police                      0.0                   0
# has_secondary_use_other                           0.0                   0
#
#                                         Outliers (%)                    Note
# Feature
# geo_level_1_id                                  0.00
# geo_level_2_id                                  0.00
# geo_level_3_id                                  0.00
# count_floors_pre_eq                            39.90  outlier_h, outlier_l,
# age                                             0.00
# area_percentage                                 0.00
# height_percentage                               0.00
# has_superstructure_adobe_mud                    0.00
# has_superstructure_mud_mortar_stone            23.81             outlier_l,
# has_superstructure_stone_flag                   0.00
# has_superstructure_cement_mortar_stone          0.00
# has_superstructure_mud_mortar_brick             0.00
# has_superstructure_cement_mortar_brick          0.00
# has_superstructure_timber                       0.00
# has_superstructure_bamboo                       0.00
# has_superstructure_rc_non_engineered            0.00
# has_superstructure_rc_engineered                0.00
# has_superstructure_other                        0.00
# count_families                                  0.00
# has_secondary_use                              11.19             outlier_h,
# has_secondary_use_agriculture                   0.00
# has_secondary_use_hotel                         0.00
# has_secondary_use_rental                        0.00
# has_secondary_use_institution                   0.00
# has_secondary_use_school                        0.00
# has_secondary_use_industry                      0.00
# has_secondary_use_health_post                   0.00
# has_secondary_use_gov_office                    0.00
# has_secondary_use_use_police                    0.00
# has_secondary_use_other                         0.00

# %%
corr_matrix = df.corr()
l=(corr_matrix["damage_grade"]).sort_values(ascending=False)

# %% [markdown]
# ### Identifying coorelation between features using Heatmap

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(30,30))
mask=np.triu(corr_matrix)
sns.heatmap(corr_matrix,annot=True,ax=ax,mask=mask)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Categorical Data Analysis

# %% [markdown]
# ### Distribution

# %%
COL_NUMBER = 6
row_number = math.ceil(df_cat.columns.size/COL_NUMBER)
fig2, axs = pl.subplots(row_number,COL_NUMBER,figsize=(5*COL_NUMBER,5*row_number))
i = 0
for attr in df_cat.items():
    name = attr[0]
    domain = [str(key) for key in attr[1].value_counts().keys().to_list()]
    counts = attr[1].value_counts().values
    col = i%COL_NUMBER
    row = math.floor(i/COL_NUMBER)
    axs[row,col].barh(domain, counts)
    axs[row,col].set_title(name)
    i+=1

# %% [markdown]
# ### Quality Report

# %%
dm.categorical_report(df_cat)
# Out:
#                          Count  Missing (%)  Cardinality (#) Mode  Mode Freq  \
# Feature
# land_surface_condition  260601          0.0                3    t     216757
# foundation_type         260601          0.0                5    r     219196
# roof_type               260601          0.0                3    n     182842
# ground_floor_type       260601          0.0                5    f     209619
# other_floor_type        260601          0.0                4    q     165282
# position                260601          0.0                4    s     202090
# plan_configuration      260601          0.0               10    d     250072
# legal_ownership_status  260601          0.0                4    v     250939
#
#                         Mode (%) 2nd Mode  2nd Mode Freq  2nd Mode (%) Note
# Feature
# land_surface_condition     83.18        n          35528         13.63
# foundation_type            84.11        w          15118          5.80
# roof_type                  70.16        q          61576         23.63
# ground_floor_type          80.44        x          24877          9.55
# other_floor_type           63.42        x          43448         16.67
# position                   77.55        t          42896         16.46
# plan_configuration         95.96        q           5692          2.18
# legal_ownership_status     96.29        a           5512          2.12

# %% [markdown]
# ## Normalization and Transformation

# %%
df_full= pd.concat([df_num_cleaned,df_cat], axis=1)

# %%
df_full.describe()
# Out:
#        geo_level_1_id  geo_level_2_id  geo_level_3_id  count_floors_pre_eq  \
# count   260601.000000   260601.000000   260601.000000        260601.000000
# mean        13.933181      699.533958     6256.482066             2.088626
# std          7.684684      388.143621     3452.382307             0.625412
# min          4.000000      142.000000     1219.000000             1.000000
# 25%          7.000000      350.000000     3073.000000             2.000000
# 50%         12.000000      702.000000     6270.000000             2.000000
# 75%         21.000000     1050.000000     9412.000000             2.000000
# max         26.000000     1273.000000    11286.000000             3.000000
#
#                  age  area_percentage  height_percentage  \
# count  260601.000000    260601.000000      260601.000000
# mean       19.852879         7.632615           5.347209
# std        13.298994         2.784354           1.491625
# min         5.000000         4.000000           3.000000
# 25%        10.000000         5.000000           4.000000
# 50%        15.000000         7.000000           5.000000
# 75%        30.000000         9.000000           6.000000
# max        45.000000        13.000000           8.000000
#
#        has_superstructure_adobe_mud  has_superstructure_mud_mortar_stone  \
# count                      260601.0                        260601.000000
# mean                            0.0                             0.761935
# std                             0.0                             0.425900
# min                             0.0                             0.000000
# 25%                             0.0                             1.000000
# 50%                             0.0                             1.000000
# 75%                             0.0                             1.000000
# max                             0.0                             1.000000
#
#        has_superstructure_stone_flag  ...  has_secondary_use_agriculture  \
# count                       260601.0  ...                       260601.0
# mean                             0.0  ...                            0.0
# std                              0.0  ...                            0.0
# min                              0.0  ...                            0.0
# 25%                              0.0  ...                            0.0
# 50%                              0.0  ...                            0.0
# 75%                              0.0  ...                            0.0
# max                              0.0  ...                            0.0
#
#        has_secondary_use_hotel  has_secondary_use_rental  \
# count                 260601.0                  260601.0
# mean                       0.0                       0.0
# std                        0.0                       0.0
# min                        0.0                       0.0
# 25%                        0.0                       0.0
# 50%                        0.0                       0.0
# 75%                        0.0                       0.0
# max                        0.0                       0.0
#
#        has_secondary_use_institution  has_secondary_use_school  \
# count                       260601.0                  260601.0
# mean                             0.0                       0.0
# std                              0.0                       0.0
# min                              0.0                       0.0
# 25%                              0.0                       0.0
# 50%                              0.0                       0.0
# 75%                              0.0                       0.0
# max                              0.0                       0.0
#
#        has_secondary_use_industry  has_secondary_use_health_post  \
# count                    260601.0                       260601.0
# mean                          0.0                            0.0
# std                           0.0                            0.0
# min                           0.0                            0.0
# 25%                           0.0                            0.0
# 50%                           0.0                            0.0
# 75%                           0.0                            0.0
# max                           0.0                            0.0
#
#        has_secondary_use_gov_office  has_secondary_use_use_police  \
# count                      260601.0                      260601.0
# mean                            0.0                           0.0
# std                             0.0                           0.0
# min                             0.0                           0.0
# 25%                             0.0                           0.0
# 50%                             0.0                           0.0
# 75%                             0.0                           0.0
# max                             0.0                           0.0
#
#        has_secondary_use_other
# count                 260601.0
# mean                       0.0
# std                        0.0
# min                        0.0
# 25%                        0.0
# 50%                        0.0
# 75%                        0.0
# max                        0.0
#
# [8 rows x 30 columns]

# %% [markdown]
# ### Transforming the categorical Variables using ordinal encoder

# %%
o=OrdinalEncoder()
for i in df_full.columns:
    if df_full[i].dtype=="object" :
        df_full[i]=o.fit_transform(df_full[[i]])

# %% [markdown]
# #### Saving the cleaned DataSet

# %%
df_full.to_csv("Cleaned_data.csv",index=False)
